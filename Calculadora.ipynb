# %%
def calcular():
    while True:
        try:
            print("Digite os números e escolha as operações diretamente no código.")
            num1 = float(input("Digite o primeiro número: "))
            num2 = float(input("Digite o segundo número: "))
        except ValueError:
            print("Erro: valores inválidos. Por favor, insira números válidos.")
            continue

        print("\nEscolha a operação que deseja realizar:")
        print("1. Soma")
        print("2. Subtração")
        print("3. Multiplicação")
        print("4. Divisão")
        print("5. Operações Lógicas")
        print("6. Sair da operação")

        operacao = input("Escolha a operação (1/2/3/4/5/6): ")

        if operacao == "1":
            resultado = num1 + num2
            print(f"O resultado da soma é: {resultado}")
        elif operacao == "2":
            resultado = num1 - num2
            print(f"O resultado da subtração é: {resultado}")
        elif operacao == "3":
            resultado = num1 * num2
            print(f"O resultado da multiplicação é: {resultado}")
        elif operacao == "4":
            if num2 != 0:
                resultado = num1 / num2
                print(f"O resultado da divisão é: {resultado}")
            else:
                print("Erro: Não é possível dividir por zero.")
        elif operacao == "5":
            print("\nEscolha a operação lógica:")
            print("a. AND")
            print("b. OR")
            print("c. NOT")
            logica = input("Escolha a operação lógica (a/b/c): ").lower()

            if logica == "a":
                resultado = bool(num1) and bool(num2)
                print(f"O resultado de {num1} AND {num2} é: {resultado}")
            elif logica == "b":
                resultado = bool(num1) or bool(num2)
                print(f"O resultado de {num1} OR {num2} é: {resultado}")
            elif logica == "c":
                resultado = not bool(num1)
                print(f"O resultado de NOT {num1} é: {resultado}")
            else:
                print("Opção inválida para operação lógica.")
        elif operacao == "6":
            print("Saindo da aplicação...")
            break
        else:
            print("Opção inválida. Tente novamente.")

        continuar = input("\nDeseja realizar outra operação? (s/n): ").lower()
        if continuar != 's':
            print("Programa encerrado.")
            break

if __name__ == "__main__":
    print("\n--- Calculadora de Operações ---")
    calcular()
# Out:
# --- Calculadora de Operações ---
# Digite os números e escolha as operações diretamente no código.
# Digite o primeiro número: 6
# Digite o segundo número: 9
#
# Escolha a operação que deseja realizar:
# 1. Soma
# 2. Subtração
# 3. Multiplicação
# 4. Divisão
# 5. Operações Lógicas
# 6. Sair da operação
# Escolha a operação (1/2/3/4/5/6): 3
# O resultado da multiplicação é: 54.0
#
# Deseja realizar outra operação? (s/n): s
# Digite os números e escolha as operações diretamente no código.
# Digite o primeiro número: 1
# Digite o segundo número: 2
#
# Escolha a operação que deseja realizar:
# 1. Soma
# 2. Subtração
# 3. Multiplicação
# 4. Divisão
# 5. Operações Lógicas
# 6. Sair da operação
# Escolha a operação (1/2/3/4/5/6): 4
# O resultado da divisão é: 0.5
#
# Deseja realizar outra operação? (s/n): n
# Programa encerrado.
